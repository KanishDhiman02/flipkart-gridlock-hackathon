# %%
conda install -c conda-forge lightgbm -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - lightgbm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-cpp-1.84.0           |       hca5e981_3          16 KB  conda-forge
#     ca-certificates-2026.5.20  |       hbd8a1cb_0         127 KB  conda-forge
#     certifi-2026.5.20          |     pyhd8ed1ab_0         131 KB  conda-forge
#     conda-24.11.3              |  py312h81bd7bf_0         1.1 MB  conda-forge
#     icu-73.2                   |       hc8870d7_0        11.4 MB  conda-forge
#     khronos-opencl-icd-loader-2024.10.24|       h5505292_1          34 KB  conda-forge
#     libboost-1.84.0            |       h17eb2be_3         1.9 MB  conda-forge
#     libboost-devel-1.84.0      |       hf450f58_3          39 KB  conda-forge
#     libboost-headers-1.84.0    |       hce30654_3        13.2 MB  conda-forge
#     libcxx-22.1.7              |       h55c6f16_0         555 KB  conda-forge
#     libexpat-2.6.3             |       hf9b8971_0          62 KB  conda-forge
#     liblightgbm-4.6.0          |   cpu_h0bc706f_0         1.3 MB  conda-forge
#     libsqlite-3.46.0           |       hfb93653_0         811 KB  conda-forge
#     libzlib-1.2.13             |       hfb2fe0b_6          46 KB  conda-forge
#     lightgbm-4.6.0             |         cpu_py_0          84 KB  conda-forge
#     llvm-openmp-22.1.7         |       hc7d1edf_0         278 KB  conda-forge
#     opencl-headers-2025.06.13  |       hf6b4638_0          55 KB  conda-forge
#     openssl-3.6.2              |       hd24854e_0         3.0 MB  conda-forge
#     pip-26.1.2                 |     pyh8b19718_0         1.1 MB  conda-forge
#     python-3.12.2              |hdf0ec26_0_cpython        12.5 MB  conda-forge
#     python_abi-3.12            |          8_cp312           7 KB  conda-forge
#     zlib-1.2.13                |       hfb2fe0b_6          76 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        47.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   khronos-opencl-ic~ conda-forge/osx-arm64::khronos-opencl-icd-loader-2024.10.24-h5505292_1
#   libboost-devel     conda-forge/osx-arm64::libboost-devel-1.84.0-hf450f58_3
#   libboost-headers   conda-forge/osx-arm64::libboost-headers-1.84.0-hce30654_3
#   libexpat           conda-forge/osx-arm64::libexpat-2.6.3-hf9b8971_0
#   liblightgbm        conda-forge/osx-arm64::liblightgbm-4.6.0-cpu_h0bc706f_0
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.46.0-hfb93653_0
#   libzlib            conda-forge/osx-arm64::libzlib-1.2.13-hfb2fe0b_6
#   lightgbm           conda-forge/noarch::lightgbm-4.6.0-cpu_py_0
#   opencl-headers     conda-forge/osx-arm64::opencl-headers-2025.06.13-hf6b4638_0
#   pip                conda-forge/noarch::pip-26.1.2-pyh8b19718_0
#   python_abi         conda-forge/noarch::python_abi-3.12-8_cp312
#
# The following packages will be UPDATED:
#
#   boost-cpp          pkgs/main::boost-cpp-1.82.0-h48ca7d4_2 --> conda-forge::boost-cpp-1.84.0-hca5e981_3
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-~ --> conda-forge/noarch::ca-certificates-2026.5.20-hbd8a1cb_0
#   certifi            pkgs/main/osx-arm64::certifi-2025.8.3~ --> conda-forge/noarch::certifi-2026.5.20-pyhd8ed1ab_0
#   icu                        pkgs/main::icu-73.1-h313beb8_0 --> conda-forge::icu-73.2-hc8870d7_0
#   libboost            pkgs/main::libboost-1.82.0-h0bc93f9_2 --> conda-forge::libboost-1.84.0-h17eb2be_3
#   libcxx                pkgs/main::libcxx-14.0.6-h848a8c0_0 --> conda-forge::libcxx-22.1.7-h55c6f16_0
#   llvm-openmp        pkgs/main::llvm-openmp-14.0.6-hc6e570~ --> conda-forge::llvm-openmp-22.1.7-hc7d1edf_0
#   openssl              pkgs/main::openssl-3.0.17-h4ee41c1_0 --> conda-forge::openssl-3.6.2-hd24854e_0
#   zlib                    pkgs/main::zlib-1.2.13-h18a0788_1 --> conda-forge::zlib-1.2.13-hfb2fe0b_6
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-24.11.3-py312hca03da~ --> conda-forge::conda-24.11.3-py312h81bd7bf_0
#   python                pkgs/main::python-3.12.7-h99e199e_0 --> conda-forge::python-3.12.2-hdf0ec26_0_cpython
#
#
#
# Downloading and Extracting Packages:
# libboost-headers-1.8 | 13.2 MB   |                                       |   0%
# python-3.12.2        | 12.5 MB   |                                       |   0%
#
# icu-73.2             | 11.4 MB   |                                       |   0%
#
#
# openssl-3.6.2        | 3.0 MB    |                                       |   0%
#
#
#
# libboost-1.84.0      | 1.9 MB    |                                       |   0%
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    |                                       |   0%
#
#
#
#
#
# pip-26.1.2           | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# llvm-openmp-22.1.7   | 278 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# certifi-2026.5.20    | 131 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 127 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# lightgbm-4.6.0       | 84 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 76 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.6.3       | 62 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opencl-headers-2025. | 55 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 46 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-devel-1.84. | 39 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# khronos-opencl-icd-l | 34 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# boost-cpp-1.84.0     | 16 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 7 KB      |                                       |   0%
#
#
# openssl-3.6.2        | 3.0 MB    | 1                                     |   1%
#
#
# openssl-3.6.2        | 3.0 MB    | #5                                    |   4%
#
# icu-73.2             | 11.4 MB   |                                       |   0%
#
#
# openssl-3.6.2        | 3.0 MB    | ###3                                  |   9%
# python-3.12.2        | 12.5 MB   |                                       |   0%
#
# icu-73.2             | 11.4 MB   | 4                                     |   1%
#
#
# openssl-3.6.2        | 3.0 MB    | #######8                              |  21%
# python-3.12.2        | 12.5 MB   | 3                                     |   1%
#
#
# openssl-3.6.2        | 3.0 MB    | ###############8                      |  43%
#
# libboost-headers-1.8 | 13.2 MB   |                                       |   0%
# python-3.12.2        | 12.5 MB   | 5                                     |   2%
#
#
#
# libboost-1.84.0      | 1.9 MB    | 3                                     |   1%
#
#
# openssl-3.6.2        | 3.0 MB    | #####################2                |  57%
#
#
#
# libboost-headers-1.8 | 13.2 MB   | 2                                     |   1%
#
# icu-73.2             | 11.4 MB   | #3                                    |   4%
# libboost-headers-1.8 | 13.2 MB   | 3                                     |   1%
#
#
# openssl-3.6.2        | 3.0 MB    | #########################3            |  69%
#
#
#
# libboost-1.84.0      | 1.9 MB    | #8                                    |   5%
#
# libboost-headers-1.8 | 13.2 MB   | 4                                     |   1%
# python-3.12.2        | 12.5 MB   | #4                                    |   4%
#
# icu-73.2             | 11.4 MB   | ##3                                   |   6%
#
#
# openssl-3.6.2        | 3.0 MB    | ############################6         |  78%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ##4                                   |   7%
#
# icu-73.2             | 11.4 MB   | ###5                                  |  10%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ####6                                 |  12%
#
#
# libboost-headers-1.8 | 13.2 MB   | 7                                     |   2%
# python-3.12.2        | 12.5 MB   | ##2                                   |   6%
#
#
# openssl-3.6.2        | 3.0 MB    | ##################################### | 100%
#
#
# openssl-3.6.2        | 3.0 MB    | ##################################### | 100%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ######4                               |  17%
#
# icu-73.2             | 11.4 MB   | ####                                  |  11%
# libboost-headers-1.8 | 13.2 MB   | #                                     |   3%
#
#
#
# libboost-1.84.0      | 1.9 MB    | #######6                              |  21%
#
# icu-73.2             | 11.4 MB   | #####                                 |  14%
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | 4                                     |   1%
# python-3.12.2        | 12.5 MB   | ###4                                  |   9%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ########9                             |  24%
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ##2                                   |   6%
# python-3.12.2        | 12.5 MB   | ###7                                  |  10%
#
# icu-73.2             | 11.4 MB   | #####7                                |  15%
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ##########1                           |  27%
# libboost-headers-1.8 | 13.2 MB   | #4                                    |   4%
#
#
#
# libboost-1.84.0      | 1.9 MB    | #########8                            |  27%
# python-3.12.2        | 12.5 MB   | #####                                 |  14%
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ##################                    |  49%
#
# libboost-headers-1.8 | 13.2 MB   | #8                                    |   5%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ##########7                           |  29%
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ##################################### | 100%
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | #####4                                |  15%
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ##################################### | 100%
#
# libboost-headers-1.8 | 13.2 MB   | ##3                                   |   6%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ############9                         |  35%
# python-3.12.2        | 12.5 MB   | #####9                                |  16%
#
#
#
#
#
# pip-26.1.2           | 1.1 MB    | 5                                     |   1%
#
# libboost-headers-1.8 | 13.2 MB   | ##5                                   |   7%
#
#
#
#
#
# pip-26.1.2           | 1.1 MB    | #####5                                |  15%
# python-3.12.2        | 12.5 MB   | ######4                               |  17%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ##############7                       |  40%
#
# icu-73.2             | 11.4 MB   | ########2                             |  22%
#
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ##8                                   |   8%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ################                      |  43%
#
# icu-73.2             | 11.4 MB   | ########8                             |  24%
#
#
#
#
#
# pip-26.1.2           | 1.1 MB    | ##################1                   |  49%
# python-3.12.2        | 12.5 MB   | ######8                               |  18%
# python-3.12.2        | 12.5 MB   | #######1                              |  19%
#
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ###                                   |   8%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ################9                     |  46%
#
# icu-73.2             | 11.4 MB   | #########2                            |  25%
#
#
#
#
#
# pip-26.1.2           | 1.1 MB    | #############################7        |  80%
#
#
#
#
#
# pip-26.1.2           | 1.1 MB    | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ###4                                  |   9%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ####################6                 |  56%
#
# icu-73.2             | 11.4 MB   | ###########3                          |  31%
# python-3.12.2        | 12.5 MB   | ########8                             |  24%
#
#
#
#
#
# pip-26.1.2           | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ###9                                  |  11%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ######################4               |  61%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ######7                               |  18%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ########################3             |  66%
# python-3.12.2        | 12.5 MB   | #########4                            |  26%
#
# icu-73.2             | 11.4 MB   | ############1                         |  33%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##########3                           |  28%
# libboost-headers-1.8 | 13.2 MB   | ####2                                 |  11%
#
#
#
# libboost-1.84.0      | 1.9 MB    | #########################8            |  70%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | #############9                        |  38%
#
# libboost-headers-1.8 | 13.2 MB   | ####5                                 |  12%
# python-3.12.2        | 12.5 MB   | ##########7                           |  29%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ####################1                 |  54%
# python-3.12.2        | 12.5 MB   | ###########2                          |  30%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ########################2             |  65%
#
# icu-73.2             | 11.4 MB   | #############3                        |  36%
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ####9                                 |  13%
#
# icu-73.2             | 11.4 MB   | #############8                        |  37%
# libboost-headers-1.8 | 13.2 MB   | #####1                                |  14%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ############################3         |  77%
#
#
#
# libboost-1.84.0      | 1.9 MB    | #############################2        |  79%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################################### | 100%
#
# icu-73.2             | 11.4 MB   | ##############4                       |  39%
# libboost-headers-1.8 | 13.2 MB   | #####6                                |  15%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ################################6     |  88%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################################### | 100%
#
# libboost-headers-1.8 | 13.2 MB   | #####9                                |  16%
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | 7                                     |   2%
# python-3.12.2        | 12.5 MB   | #############1                        |  35%
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ######2                               |  17%
#
# icu-73.2             | 11.4 MB   | ###############8                      |  43%
#
#
#
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ######5                               |  18%
# python-3.12.2        | 12.5 MB   | #############6                        |  37%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ###################################6  |  96%
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | #################5                    |  47%
#
# icu-73.2             | 11.4 MB   | ################3                     |  44%
# python-3.12.2        | 12.5 MB   | ##############                        |  38%
#
#
#
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ######8                               |  18%
#
# icu-73.2             | 11.4 MB   | ################8                     |  46%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ####################################9 | 100%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | #######3                              |  20%
#
#
#
# libboost-1.84.0      | 1.9 MB    | ##################################### | 100%
#
# icu-73.2             | 11.4 MB   | #################4                    |  47%
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | #######7                              |  21%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | #                                     |   3%
#
# icu-73.2             | 11.4 MB   | #################9                    |  49%
# libboost-headers-1.8 | 13.2 MB   | ########                              |  22%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | #####3                                |  14%
#
#
#
#
#
#
#
#
#
# llvm-openmp-22.1.7   | 278 KB    | ##1                                   |   6%
#
# icu-73.2             | 11.4 MB   | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
# llvm-openmp-22.1.7   | 278 KB    | ############7                         |  34%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | #########6                            |  26%
#
#
#
#
#
#
#
#
#
# llvm-openmp-22.1.7   | 278 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# llvm-openmp-22.1.7   | 278 KB    | ##################################### | 100%
#
# libboost-headers-1.8 | 13.2 MB   | ########4                             |  23%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
# certifi-2026.5.20    | 131 KB    | ####5                                 |  12%
# python-3.12.2        | 12.5 MB   | ###############7                      |  42%
#
# libboost-headers-1.8 | 13.2 MB   | #########                             |  24%
#
#
#
#
#
#
#
#
#
#
# certifi-2026.5.20    | 131 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# certifi-2026.5.20    | 131 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | #########4                            |  25%
#
# icu-73.2             | 11.4 MB   | ###################9                  |  54%
# python-3.12.2        | 12.5 MB   | ################5                     |  45%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 127 KB    | ####6                                 |  13%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | #####################3                |  58%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 127 KB    | ##################################### | 100%
#
# libboost-headers-1.8 | 13.2 MB   | #########7                            |  26%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 127 KB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | #################                     |  46%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | ########################5             |  66%
#
# icu-73.2             | 11.4 MB   | ####################7                 |  56%
# libboost-headers-1.8 | 13.2 MB   | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
#
#
#
# lightgbm-4.6.0       | 84 KB     | #######                               |  19%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | ##############################9       |  84%
#
# icu-73.2             | 11.4 MB   | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
# lightgbm-4.6.0       | 84 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# lightgbm-4.6.0       | 84 KB     | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ##########6                           |  29%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | ###################################2  |  95%
#
# icu-73.2             | 11.4 MB   | #####################5                |  58%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libcxx-22.1.7        | 555 KB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | ##################5                   |  50%
#
# icu-73.2             | 11.4 MB   | ######################                |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 76 KB     | #######7                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 76 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ###########3                          |  31%
# python-3.12.2        | 12.5 MB   | ##################9                   |  51%
#
# icu-73.2             | 11.4 MB   | ######################6               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ############1                         |  33%
# python-3.12.2        | 12.5 MB   | ###################4                  |  53%
#
# icu-73.2             | 11.4 MB   | #######################1              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.6.3       | 62 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.6.3       | 62 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.6.3       | 62 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opencl-headers-2025. | 55 KB     | ##########8                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opencl-headers-2025. | 55 KB     | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ############7                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opencl-headers-2025. | 55 KB     | ##################################### | 100%
#
# icu-73.2             | 11.4 MB   | #######################5              |  64%
# libboost-headers-1.8 | 13.2 MB   | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 46 KB     | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 46 KB     | ##################################### | 100%
#
# icu-73.2             | 11.4 MB   | ########################              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 46 KB     | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | #############7                        |  37%
#
# icu-73.2             | 11.4 MB   | ########################4             |  66%
# libboost-headers-1.8 | 13.2 MB   | ##############1                       |  38%
#
# icu-73.2             | 11.4 MB   | #########################             |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-devel-1.84. | 39 KB     | ###############2                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-devel-1.84. | 39 KB     | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-devel-1.84. | 39 KB     | ##################################### | 100%
#
# icu-73.2             | 11.4 MB   | #########################4            |  69%
# libboost-headers-1.8 | 13.2 MB   | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# khronos-opencl-icd-l | 34 KB     | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# khronos-opencl-icd-l | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# khronos-opencl-icd-l | 34 KB     | ##################################### | 100%
#
# icu-73.2             | 11.4 MB   | #########################9            |  70%
# libboost-headers-1.8 | 13.2 MB   | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 7 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 7 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.12      | 7 KB      | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ###############9                      |  43%
#
# libboost-headers-1.8 | 13.2 MB   | ################4                     |  44%
# python-3.12.2        | 12.5 MB   | #######################4              |  63%
#
# icu-73.2             | 11.4 MB   | ##########################9           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# boost-cpp-1.84.0     | 16 KB     | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# boost-cpp-1.84.0     | 16 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ################8                     |  46%
# python-3.12.2        | 12.5 MB   | #######################8              |  64%
#
# libboost-headers-1.8 | 13.2 MB   | #################3                    |  47%
# python-3.12.2        | 12.5 MB   | ########################2             |  66%
#
# icu-73.2             | 11.4 MB   | ###########################8          |  75%
# libboost-headers-1.8 | 13.2 MB   | #################8                    |  48%
#
# icu-73.2             | 11.4 MB   | ############################2         |  76%
# python-3.12.2        | 12.5 MB   | #########################2            |  68%
#
# libboost-headers-1.8 | 13.2 MB   | ##################5                   |  50%
# libboost-headers-1.8 | 13.2 MB   | ###################1                  |  52%
#
# libboost-headers-1.8 | 13.2 MB   | ###################6                  |  53%
# python-3.12.2        | 12.5 MB   | ##########################            |  70%
#
# libboost-headers-1.8 | 13.2 MB   | ####################1                 |  55%
# python-3.12.2        | 12.5 MB   | ##########################4           |  71%
#
# libboost-headers-1.8 | 13.2 MB   | ####################9                 |  57%
#
# icu-73.2             | 11.4 MB   | ##############################8       |  83%
# libboost-headers-1.8 | 13.2 MB   | #####################5                |  58%
#
# icu-73.2             | 11.4 MB   | ###############################3      |  85%
# libboost-headers-1.8 | 13.2 MB   | ######################1               |  60%
#
# icu-73.2             | 11.4 MB   | ###############################8      |  86%
# python-3.12.2        | 12.5 MB   | ###########################7          |  75%
#
# libboost-headers-1.8 | 13.2 MB   | ######################8               |  62%
# python-3.12.2        | 12.5 MB   | ############################2         |  76%
#
# libboost-headers-1.8 | 13.2 MB   | #######################4              |  63%
# python-3.12.2        | 12.5 MB   | ############################6         |  77%
#
# libboost-headers-1.8 | 13.2 MB   | ########################              |  65%
# python-3.12.2        | 12.5 MB   | #############################         |  79%
#
# libboost-headers-1.8 | 13.2 MB   | ########################6             |  67%
# python-3.12.2        | 12.5 MB   | #############################5        |  80%
#
# libboost-headers-1.8 | 13.2 MB   | #########################2            |  68%
# python-3.12.2        | 12.5 MB   | #############################9        |  81%
#
# libboost-headers-1.8 | 13.2 MB   | #########################8            |  70%
# libboost-headers-1.8 | 13.2 MB   | ##########################8           |  73%
#
# icu-73.2             | 11.4 MB   | ####################################  |  97%
# libboost-headers-1.8 | 13.2 MB   | ###########################5          |  74%
#
# icu-73.2             | 11.4 MB   | ####################################6 |  99%
#
# libboost-headers-1.8 | 13.2 MB   | ############################2         |  76%
# python-3.12.2        | 12.5 MB   | ###############################5      |  85%
#
# libboost-headers-1.8 | 13.2 MB   | #############################4        |  80%
# libboost-headers-1.8 | 13.2 MB   | ##############################2       |  82%
# libboost-headers-1.8 | 13.2 MB   | ###############################       |  84%
# libboost-headers-1.8 | 13.2 MB   | ###############################8      |  86%
# libboost-headers-1.8 | 13.2 MB   | ################################5     |  88%
# libboost-headers-1.8 | 13.2 MB   | #################################4    |  90%
# libboost-headers-1.8 | 13.2 MB   | ###################################3  |  96%
# libboost-headers-1.8 | 13.2 MB   | ####################################2 |  98%
# python-3.12.2        | 12.5 MB   | ####################################8 | 100%
# libboost-headers-1.8 | 13.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor, early_stopping, log_evaluation
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score
from scipy.optimize import minimize_scalar

df = pd.read_csv('dataset/train.csv')
df = df.drop(columns=['Index'], errors='ignore')

def engineer_features(df):
    df = df.copy()
    df[['Hour', 'Minute']] = df['timestamp'].str.split(':', expand=True).astype(int)
    df['Hour_sin']        = np.sin(2 * np.pi * df['Hour']   / 24)
    df['Hour_cos']        = np.cos(2 * np.pi * df['Hour']   / 24)
    df['Minute_sin']      = np.sin(2 * np.pi * df['Minute'] / 60)
    df['Minute_cos']      = np.cos(2 * np.pi * df['Minute'] / 60)
    df['day_of_week']     = df['day'] % 7
    df['is_weekend']      = df['day_of_week'].isin([5, 6]).astype(int)
    df['is_morning_rush'] = df['Hour'].isin([8, 9, 10]).astype(int)
    df['is_evening_rush'] = df['Hour'].isin([17, 18, 19, 20]).astype(int)
    df = df.drop(columns=['timestamp'])
    return df

df = engineer_features(df)
df = df.sort_values(['geohash', 'day', 'Hour', 'Minute']).reset_index(drop=True)

df['is_Temp_missing']     = df['Temperature'].isna().astype(int)
df['is_Weather_missing']  = df['Weather'].isna().astype(int)
df['is_RoadType_missing'] = df['RoadType'].isna().astype(int)

LAG_COLS     = [1, 2, 3, 4, 8, 12, 48, 96]
ROLL_WINDOWS = [3, 6, 12, 24]

def add_lag_features(df):
    g = df.groupby('geohash')['demand']
    for lag in LAG_COLS:
        df[f'demand_lag_{lag}'] = g.shift(lag)
    for win in ROLL_WINDOWS:
        df[f'rolling_mean_{win}'] = g.transform(
            lambda x: x.shift(1).rolling(win, min_periods=1).mean())
        df[f'rolling_std_{win}']  = g.transform(
            lambda x: x.shift(1).rolling(win, min_periods=1).std().fillna(0))
    return df

df = add_lag_features(df)

df['geo_hour_hist_mean'] = df.groupby(['geohash', 'Hour'])['demand'].transform(
    lambda x: x.shift(96).expanding().mean()
)
global_hour_mean   = df.groupby('Hour')['demand'].mean()
global_demand_mean = df['demand'].mean()

df['geo_hour_hist_mean'] = df.apply(
    lambda r: global_hour_mean[r['Hour']] if pd.isna(r['geo_hour_hist_mean'])
              else r['geo_hour_hist_mean'], axis=1
)

def decode_geohash(gh):
    base32 = '0123456789bcdefghjkmnpqrstuvwxyz'
    lat_range, lon_range = [-90.0, 90.0], [-180.0, 180.0]
    is_lon = True
    for char in gh:
        bits = base32.index(char)
        for shift in range(4, -1, -1):
            bit = (bits >> shift) & 1
            if is_lon:
                mid = sum(lon_range) / 2
                lon_range[0 if bit else 1] = mid
            else:
                mid = sum(lat_range) / 2
                lat_range[0 if bit else 1] = mid
            is_lon = not is_lon
    return (sum(lat_range) / 2, sum(lon_range) / 2)

unique_geohashes = df['geohash'].drop_duplicates()
latlon_decoded   = unique_geohashes.apply(decode_geohash)
latlon_df        = pd.DataFrame(latlon_decoded.tolist(), columns=['lat', 'lon'])
latlon_df['geohash'] = unique_geohashes.values
df = df.merge(latlon_df, on='geohash', how='left')

df['geohash_macro_4'] = df['geohash'].str[:4]
df['geohash_macro_5'] = df['geohash'].str[:5]

cat_cols = ['geohash', 'geohash_macro_4', 'geohash_macro_5',
            'RoadType', 'LargeVehicles', 'Landmarks', 'Weather']
for col in cat_cols:
    df[col] = df[col].fillna('Unknown').astype(str)

temp_median = df['Temperature'].median()
df['Temperature'] = df['Temperature'].fillna(temp_median)

FEATURE_COLS = [c for c in df.columns if c not in ['demand', 'day']]
print(f"Features ({len(FEATURE_COLS)}): {FEATURE_COLS}")

X, y = df[FEATURE_COLS], df['demand']

tscv = TimeSeriesSplit(n_splits=5)

cb_scores, lgbm_scores = [], []
cb_models, lgbm_models = [], []
last_cb_oof = last_lgbm_oof = last_y_val = None

for fold, (train_idx, val_idx) in enumerate(tscv.split(X)):
    X_tr,  X_val = X.iloc[train_idx],  X.iloc[val_idx]
    y_tr,  y_val = y.iloc[train_idx],  y.iloc[val_idx]

    # ── CatBoost ──
    cb = CatBoostRegressor(
        iterations=2000, learning_rate=0.03, depth=8, l2_leaf_reg=5,
        cat_features=cat_cols, eval_metric='R2', random_seed=42,
        verbose=200, early_stopping_rounds=50
    )
    cb.fit(X_tr, y_tr, eval_set=(X_val, y_val), use_best_model=True)
    cb_preds = cb.predict(X_val)
    cb_r2    = max(0, r2_score(y_val, cb_preds)) * 100
    cb_scores.append(cb_r2)
    cb_models.append(cb)

    # ── LightGBM ──
    X_tr_lgbm  = X_tr.copy()
    X_val_lgbm = X_val.copy()
    for col in cat_cols:
        X_tr_lgbm[col]  = X_tr_lgbm[col].astype('category')
        X_val_lgbm[col] = X_val_lgbm[col].astype('category')

    lgbm = LGBMRegressor(
        n_estimators=2000, learning_rate=0.03, num_leaves=127,
        min_child_samples=20, subsample=0.8, colsample_bytree=0.8,
        reg_alpha=0.1, reg_lambda=1.0, random_state=42
    )
    lgbm.fit(
        X_tr_lgbm, y_tr,
        eval_set=[(X_val_lgbm, y_val)],
        eval_metric='r2',
        callbacks=[early_stopping(50, verbose=False), log_evaluation(200)]
    )
    lgbm_preds = lgbm.predict(X_val_lgbm)
    lgbm_r2    = max(0, r2_score(y_val, lgbm_preds)) * 100
    lgbm_scores.append(lgbm_r2)
    lgbm_models.append(lgbm)

    print(f"Fold {fold+1} | CB R²: {cb_r2:.2f} | LGBM R²: {lgbm_r2:.2f}")
    last_cb_oof, last_lgbm_oof, last_y_val = cb_preds, lgbm_preds, y_val

print(f"\nMean CV — CatBoost: {np.mean(cb_scores):.2f} | LGBM: {np.mean(lgbm_scores):.2f}")

def neg_r2_blend(w):
    blended = w * last_cb_oof + (1 - w) * last_lgbm_oof
    return -(max(0, r2_score(last_y_val, blended)) * 100)

result = minimize_scalar(neg_r2_blend, bounds=(0, 1), method='bounded')
best_w = result.x
print(f"Optimal blend — CB: {best_w:.3f} | LGBM: {1-best_w:.3f}")
print(f"Blended R² last fold: {-result.fun:.2f}")

best_cb_iters   = int(np.mean([m.get_best_iteration() for m in cb_models]))
best_lgbm_iters = int(np.mean([m.best_iteration_ for m in lgbm_models]))
print(f"Final iters — CB: {best_cb_iters} | LGBM: {best_lgbm_iters}")

final_cb = CatBoostRegressor(
    iterations=best_cb_iters, learning_rate=0.03, depth=8, l2_leaf_reg=5,
    cat_features=cat_cols, random_seed=42, verbose=200
)
final_cb.fit(X, y)

X_lgbm = X.copy()
for col in cat_cols:
    X_lgbm[col] = X_lgbm[col].astype('category')

final_lgbm = LGBMRegressor(
    n_estimators=best_lgbm_iters, learning_rate=0.03, num_leaves=127,
    min_child_samples=20, subsample=0.8, colsample_bytree=0.8,
    reg_alpha=0.1, reg_lambda=1.0, random_state=42, verbose=100
)
final_lgbm.fit(X_lgbm, y)

─
test_raw = pd.read_csv('dataset/test.csv')

test_df = engineer_features(test_raw)      
test_df['is_Temp_missing']     = test_df['Temperature'].isna().astype(int)
test_df['is_Weather_missing']  = test_df['Weather'].isna().astype(int)
test_df['is_RoadType_missing'] = test_df['RoadType'].isna().astype(int)
test_df['Temperature']         = test_df['Temperature'].fillna(temp_median)
test_df['is_test']             = 1
test_df['demand']              = np.nan


test_df = test_df.merge(latlon_df, on='geohash', how='left')
missing_mask = test_df['lat'].isna()
if missing_mask.any():
    unseen = test_df.loc[missing_mask, 'geohash'].unique()
    print(f"Decoding {len(unseen)} unseen geohashes...")
    for gh in unseen:
        lat, lon = decode_geohash(gh)
        test_df.loc[test_df['geohash'] == gh, 'lat'] = lat
        test_df.loc[test_df['geohash'] == gh, 'lon'] = lon

test_df['geohash_macro_4'] = test_df['geohash'].str[:4]
test_df['geohash_macro_5'] = test_df['geohash'].str[:5]
for col in cat_cols:
    test_df[col] = test_df[col].fillna('Unknown').astype(str)


train_history            = df[['geohash', 'day', 'Hour', 'Minute', 'demand']].copy()
train_history['is_test'] = 0
train_history['Index']   = -1          # dummy index for train rows

static_cols = [
    'Index', 'geohash', 'day', 'Hour', 'Minute', 'demand', 'is_test',
    'RoadType', 'NumberofLanes', 'LargeVehicles', 'Landmarks',
    'Temperature', 'Weather',
    'Hour_sin', 'Hour_cos', 'Minute_sin', 'Minute_cos',
    'day_of_week', 'is_weekend', 'is_morning_rush', 'is_evening_rush',
    'is_Temp_missing', 'is_Weather_missing', 'is_RoadType_missing',
    'lat', 'lon', 'geohash_macro_4', 'geohash_macro_5'
]

combined = pd.concat(
    [train_history,
     test_df[[c for c in static_cols if c in test_df.columns]]],
    ignore_index=True
)
combined = combined.sort_values(['geohash', 'day', 'Hour', 'Minute']).reset_index(drop=True)


lag_roll_cols = (
    [f'demand_lag_{lag}' for lag in LAG_COLS] +
    [f'rolling_mean_{win}' for win in ROLL_WINDOWS] +
    [f'rolling_std_{win}'  for win in ROLL_WINDOWS] +
    ['geo_hour_hist_mean']
)
for col in lag_roll_cols:
    combined[col] = np.nan


numeric_medians = {
    col: df[col].median()
    for col in FEATURE_COLS
    if col in df.columns and pd.api.types.is_numeric_dtype(df[col])
}

print(f"Combined shape: {combined.shape} | Test rows: {(combined['is_test']==1).sum()}")


all_geohashes = combined['geohash'].unique()
print(f"\nForecasting across {len(all_geohashes)} geohashes...")

for gh_num, gh in enumerate(all_geohashes):
    if gh_num % 100 == 0:
        print(f"  Geohash {gh_num}/{len(all_geohashes)}")

    gh_mask = combined['geohash'] == gh
    gh_idx  = combined.index[gh_mask].tolist()   

    if not combined.loc[gh_idx, 'is_test'].any():
        continue


    for pos, idx in enumerate(gh_idx):
        is_test_row = combined.at[idx, 'is_test'] == 1


        geo_mean = global_hour_mean.get(combined.at[idx, 'Hour'], global_demand_mean)
        combined.at[idx, 'geo_hour_hist_mean'] = geo_mean


        for lag in LAG_COLS:
            lag_pos = pos - lag
            if lag_pos >= 0:
                val = combined.at[gh_idx[lag_pos], 'demand']
                combined.at[idx, f'demand_lag_{lag}'] = val if not pd.isna(val) else geo_mean
            else:
                combined.at[idx, f'demand_lag_{lag}'] = geo_mean


        for win in ROLL_WINDOWS:
            past = [
                combined.at[gh_idx[pos - k], 'demand']
                for k in range(1, min(win + 1, pos + 1))
                if not pd.isna(combined.at[gh_idx[pos - k], 'demand'])
            ]
            combined.at[idx, f'rolling_mean_{win}'] = np.mean(past) if past else geo_mean
            combined.at[idx, f'rolling_std_{win}']  = np.std(past)  if len(past) > 1 else 0.0


        if not is_test_row:
            continue


        row = combined.loc[[idx], FEATURE_COLS].copy()
        for col in cat_cols:
            row[col] = row[col].fillna('Unknown').astype(str)


        for col in FEATURE_COLS:
            if row[col].isna().any():
                row[col] = row[col].fillna(numeric_medians.get(col, 0.0))

        row_lgbm = row.copy()
        for col in cat_cols:
            row_lgbm[col] = row_lgbm[col].astype('category')

        pred_cb   = final_cb.predict(row)[0]
        pred_lgbm = final_lgbm.predict(row_lgbm)[0]
        combined.at[idx, 'demand'] = max(0.0, best_w * pred_cb + (1 - best_w) * pred_lgbm)


test_rows    = combined[combined['is_test'] == 1][FEATURE_COLS]
nan_frac     = test_rows.isna().mean()
problem_cols = nan_frac[nan_frac > 0].sort_values(ascending=False)
if len(problem_cols) > 0:
    print("\n⚠ WARNING — NaN features remaining:")
    print(problem_cols.head(15))
else:
    print("\n✓ No NaN features — good to go")



final_test = combined[combined['is_test'] == 1][['Index', 'demand']].copy()
final_test['demand'] = final_test['demand'].clip(lower=0)
final_test = final_test.sort_values('Index').reset_index(drop=True)
final_test.to_csv('submission.csv', index=False)

print(f"\nDone.")
print(f"Rows       : {len(final_test)}")
print(f"Mean demand: {final_test['demand'].mean():.4f}")
print(f"Min  demand: {final_test['demand'].min():.4f}")
print(f"Max  demand: {final_test['demand'].max():.4f}")
# Out:
# Features (41): ['geohash', 'RoadType', 'NumberofLanes', 'LargeVehicles', 'Landmarks', 'Temperature', 'Weather', 'Hour', 'Minute', 'Hour_sin', 'Hour_cos', 'Minute_sin', 'Minute_cos', 'day_of_week', 'is_weekend', 'is_morning_rush', 'is_evening_rush', 'is_Temp_missing', 'is_Weather_missing', 'is_RoadType_missing', 'demand_lag_1', 'demand_lag_2', 'demand_lag_3', 'demand_lag_4', 'demand_lag_8', 'demand_lag_12', 'demand_lag_48', 'demand_lag_96', 'rolling_mean_3', 'rolling_std_3', 'rolling_mean_6', 'rolling_std_6', 'rolling_mean_12', 'rolling_std_12', 'rolling_mean_24', 'rolling_std_24', 'geo_hour_hist_mean', 'lat', 'lon', 'geohash_macro_4', 'geohash_macro_5']
# 0:	learn: 0.0503564	test: -0.0430058	best: -0.0430058 (0)	total: 12.9ms	remaining: 25.8s
# 200:	learn: 0.9356738	test: 0.9160313	best: 0.9160313 (200)	total: 1.9s	remaining: 17s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9168417855
# bestIteration = 222
#
# Shrink model to first 223 iterations.
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.933623
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.269673
# [LightGBM] [Debug] init for col-wise cost 0.000434 seconds, init for row-wise cost 0.002256 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000842 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 4562
# [LightGBM] [Info] Number of data points in the train set: 12884, number of used features: 41
# [LightGBM] [Info] Start training from score 0.081028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 105 and depth = 14
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 113 and depth = 14
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 112 and depth = 12
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 119 and depth = 14
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 112 and depth = 13
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 119 and depth = 14
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 119 and depth = 14
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 125 and depth = 12
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 118 and depth = 15
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 114 and depth = 12
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 124 and depth = 15
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 120 and depth = 16
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 118 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# Fold 1 | CB R²: 91.68 | LGBM R²: 93.33
# 0:	learn: 0.0507237	test: -0.0111446	best: -0.0111446 (0)	total: 14.2ms	remaining: 28.5s
# 200:	learn: 0.9648265	test: 0.9127349	best: 0.9127349 (200)	total: 2.72s	remaining: 24.4s
# 400:	learn: 0.9697271	test: 0.9143582	best: 0.9144595 (384)	total: 5.6s	remaining: 22.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9144595136
# bestIteration = 384
#
# Shrink model to first 385 iterations.
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.931482
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.269479
# [LightGBM] [Debug] init for col-wise cost 0.000776 seconds, init for row-wise cost 0.002146 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001355 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 4848
# [LightGBM] [Info] Number of data points in the train set: 25767, number of used features: 41
# [LightGBM] [Info] Start training from score 0.098452
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# Fold 2 | CB R²: 91.45 | LGBM R²: 90.93
# 0:	learn: 0.0519731	test: 0.0339611	best: 0.0339611 (0)	total: 27.9ms	remaining: 55.8s
# 200:	learn: 0.9568355	test: 0.9573840	best: 0.9577815 (183)	total: 3.5s	remaining: 31.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9577814892
# bestIteration = 183
#
# Shrink model to first 184 iterations.
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.934282
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.248540
# [LightGBM] [Debug] init for col-wise cost 0.000870 seconds, init for row-wise cost 0.001774 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001902 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Dense Multi-Val Bin
# [LightGBM] [Info] Total Bins 5087
# [LightGBM] [Info] Number of data points in the train set: 38650, number of used features: 41
# [LightGBM] [Info] Start training from score 0.090226
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# Fold 3 | CB R²: 95.78 | LGBM R²: 95.51
# 0:	learn: 0.0533647	test: 0.0432284	best: 0.0432284 (0)	total: 22.8ms	remaining: 45.5s
# 200:	learn: 0.9615384	test: 0.9653745	best: 0.9653745 (200)	total: 4.38s	remaining: 39.2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9655170065
# bestIteration = 249
#
# Shrink model to first 250 iterations.
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.933531
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.248209
# [LightGBM] [Debug] init for col-wise cost 0.001183 seconds, init for row-wise cost 0.002996 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002504 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Dense Multi-Val Bin
# [LightGBM] [Info] Total Bins 5249
# [LightGBM] [Info] Number of data points in the train set: 51533, number of used features: 41
# [LightGBM] [Info] Start training from score 0.095633
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# ...
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 26
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 27
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 23
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 24
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# Fold 5 | CB R²: 92.68 | LGBM R²: 92.58
#
# Mean CV — CatBoost: 93.63 | LGBM: 93.86
# Optimal blend — CB: 0.625 | LGBM: 0.375
# Blended R² last fold: 92.74
# Final iters — CB: 243 | LGBM: 115
# 0:	learn: 0.1382905	total: 49.8ms	remaining: 12.1s
# 200:	learn: 0.0267132	total: 6.13s	remaining: 1.28s
# 242:	learn: 0.0264346	total: 7.47s	remaining: 0us
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.934067
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.248458
# [LightGBM] [Debug] init for col-wise cost 0.001529 seconds, init for row-wise cost 0.003483 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003538 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Dense Multi-Val Bin
# [LightGBM] [Info] Total Bins 5686
# [LightGBM] [Info] Number of data points in the train set: 77299, number of used features: 41
# [LightGBM] [Info] Start training from score 0.093942
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 11
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 21
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 12
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 13
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 19
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 22
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 20
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 18
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 25
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 17
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 16
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 15
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 14
# [LightGBM] [Debug] Trained a tree with leaves = 127 and depth = 25
# Decoding 10 unseen geohashes...
# Combined shape: (119077, 45) | Test rows: 41778
#
# Forecasting across 1259 geohashes...
#   Geohash 0/1259
#   Geohash 100/1259
#   Geohash 200/1259
#   Geohash 300/1259
#   Geohash 400/1259
#   Geohash 500/1259
#   Geohash 600/1259
#   Geohash 700/1259
#   Geohash 800/1259
#   Geohash 900/1259
#   Geohash 1000/1259
#   Geohash 1100/1259
#   Geohash 1200/1259
#
# ✓ No NaN features — good to go
#
# Done.
# Rows       : 41778
# Mean demand: 0.1182
# Min  demand: 0.0081
# Max  demand: 0.9885

# %%
# Out:
# hi
